# %%
# !git clone https://github.com/vikhyat/moondream.git
# Out:
# Cloning into 'moondream'...
# remote: Enumerating objects: 413, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 413 (delta 149), reused 132 (delta 132), pack-reused 243
# Receiving objects: 100% (413/413), 645.63 KiB | 16.99 MiB/s, done.
# Resolving deltas: 100% (269/269), done.

# %%
# %cd moondream/
# !pip install -r requirements.txt
# Out:
# /content/moondream
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.1/330.1 kB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 52.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 86.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 91.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 62.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 74.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 48.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 56.4 MB/s eta 0:00:00
# ...

# %%
# !python sample.py --image '/content/street.jpg' --prompt 'Describe the image'
# Out:
# tokenizer_config.json: 100% 7.34k/7.34k [00:00<00:00, 21.9MB/s]
# vocab.json: 100% 798k/798k [00:00<00:00, 25.5MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 24.9MB/s]
# tokenizer.json: 100% 2.11M/2.11M [00:00<00:00, 33.9MB/s]
# added_tokens.json: 100% 1.08k/1.08k [00:00<00:00, 3.88MB/s]
# special_tokens_map.json: 100% 441/441 [00:00<00:00, 1.02MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 323/323 [00:00<00:00, 1.20MB/s]
# model.safetensors: 100% 3.72G/3.72G [00:29<00:00, 125MB/s]
# generation_config.json: 100% 69.0/69.0 [00:00<00:00, 260kB/s]
# > Describe the image
# The image is a black and white photo of a busy city street with multiple people walking down the sidewalk. A man wearing a tie and a suit is walking down the street, surrounded by other pedestrians. Some of the people are carrying handbags, while one person has a backpack.
#
# ...

# %%
import cv2
img1=cv2.imread('/content/street.jpg')
img1
# Out:
# array([[[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [204, 204, 204],
#         [188, 188, 188],
#         [ 54,  54,  54]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [129, 129, 129],
#         [213, 213, 213],
#         [155, 155, 155]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [ 89,  89,  89],
#         [215, 215, 215],
#         [146, 146, 146]],
#
#        ...,
#
#        [[ 14,  14,  14],
#         [ 15,  15,  15],
#         [ 15,  15,  15],
#         ...,
#         [ 24,  24,  24],
#         [ 27,  27,  27],
#         [ 34,  34,  34]],
#
#        [[  2,   2,   2],
#         [  6,   6,   6],
#         [  5,   5,   5],
#         ...,
#         [ 33,  33,  33],
#         [ 25,  25,  25],
#         [ 51,  51,  51]],
#
#        [[ 22,  22,  22],
#         [ 22,  22,  22],
#         [  7,   7,   7],
# ...

# %%
img1=cv2.imread('/content/street.jpg')
# !python sample.py --image '/content/street.jpg' --prompt 'what is the masked man carrying'
img1
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# > what is the masked man carrying
# The masked man is carrying a handbag while walking down the street.
# array([[[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [204, 204, 204],
#         [188, 188, 188],
#         [ 54,  54,  54]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [129, 129, 129],
#         [213, 213, 213],
#         [155, 155, 155]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [ 89,  89,  89],
#         [215, 215, 215],
#         [146, 146, 146]],
#
#        ...,
#
#        [[ 14,  14,  14],
#         [ 15,  15,  15],
#         [ 15,  15,  15],
#         ...,
#         [ 24,  24,  24],
#         [ 27,  27,  27],
#         [ 34,  34,  34]],
#
#        [[  2,   2,   2],
# ...

# %%
# !python sample.py --image '/content/street.jpg' --prompt 'what is the girl on the cycle wearing'
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# > what is the girl on the cycle wearing
# The girl on the cycle is wearing a tie, which is a formal accessory typically worn with a suit or other dressy attire.
