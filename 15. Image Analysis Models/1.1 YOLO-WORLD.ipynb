# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.0/716.0 kB 8.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLOWorld

model = YOLOWorld('yolov8s-world.pt')
results =model.predict('/content/street.jpg',save=True, device='cpu')
# Out:
# ...
# 100%|██████████| 25.9M/25.9M [00:00<00:00, 250MB/s]
# WARNING ⚠️ yolov8s-world.pt appears to require 'dill', which is not in ultralytics requirements.
# AutoInstall will run now for 'dill' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement ['dill'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.4s, installed 1 package: ['dill']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# image 1/1 /content/street.jpg: 448x640 7 persons, 1 bicycle, 2 handbags, 1 tie, 717.7ms
# Speed: 18.0ms preprocess, 717.7ms inference, 23.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
import cv2
img=cv2.imread('/content/runs/detect/predict/street.jpg')
img
# Out:
# array([[[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [202, 202, 202],
#         [188, 188, 188],
#         [ 56,  56,  56]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [129, 129, 129],
#         [214, 214, 214],
#         [153, 153, 153]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [ 92,  92,  92],
#         [218, 218, 218],
#         [147, 147, 147]],
#
#        ...,
#
#        [[ 15,  15,  15],
#         [ 17,  17,  17],
#         [ 14,  14,  14],
#         ...,
#         [ 25,  25,  25],
#         [ 25,  25,  25],
#         [ 37,  37,  37]],
#
#        [[  1,   1,   1],
#         [  5,   5,   5],
#         [  1,   1,   1],
#         ...,
#         [ 34,  34,  34],
#         [ 22,  22,  22],
#         [ 50,  50,  50]],
#
#        [[ 22,  22,  22],
#         [ 24,  24,  24],
#         [  6,   6,   6],
# ...

# %%
results =model.predict('/content/street2.jpg',save=True, device='cpu')
img=cv2.imread('/content/runs/detect/predict/street2.jpg')
img
# Out:
# image 1/1 /content/street2.jpg: 384x640 10 persons, 2 stop signs, 1 dog, 1 umbrella, 1 handbag, 512.8ms
# Speed: 3.4ms preprocess, 512.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# array([[[ 87,  74, 160],
#         [ 47,  32, 130],
#         [ 26,   7, 134],
#         ...,
#         [ 59,  58,  54],
#         [ 46,  45,  41],
#         [ 20,  19,  15]],
#
#        [[114, 100, 188],
#         [ 55,  41, 142],
#         [ 34,  16, 141],
#         ...,
#         [ 46,  45,  41],
#         [ 44,  43,  39],
#         [ 19,  18,  14]],
#
#        [[120, 108, 198],
#         [ 53,  41, 141],
#         [ 33,  17, 142],
#         ...,
#         [ 33,  34,  30],
#         [ 33,  32,  28],
#         [ 15,  14,  10]],
#
#        ...,
#
#        [[ 41,  41,  41],
#         [ 53,  53,  53],
#         [ 57,  59,  59],
#         ...,
#         [ 34,  46,  46],
#         [ 28,  40,  40],
#         [ 26,  38,  38]],
#
# ...

# %%
model.set_classes(['person','handbag'])
results =model.predict('/content/street2.jpg',save=True, device='cpu')
img=cv2.imread('/content/runs/detect/predict/street2.jpg')
img
# Out:
# requirements: Ultralytics requirement ['git+https://github.com/openai/CLIP.git'] not found, attempting AutoUpdate...
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-40dhpl28
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 3.1 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369497 sha256=3b62525128bb7c4f32ef379ec03e1017e6c57117bce86ad7cd2b9d36f823ef04
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qrp09bm0/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# ...
#
# requirements: AutoUpdate success ✅ 10.1s, installed 1 package: ['git+https://github.com/openai/CLIP.git']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# ...

# %%
from ultralytics import YOLO

model=YOLO('yolov8s-world.pt')
model.set_classes(['tie','person'])
model.save('custom_yolovs.pt')

# %%
model= YOLO('/content/custom_yolovs.pt')
results =model.predict('/content/street2.jpg',save=True, device='cpu')
# Out:
# image 1/1 /content/street2.jpg: 384x640 5 persons, 496.5ms
# Speed: 2.8ms preprocess, 496.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict4

# %%
img=cv2.imread('/content/runs/detect/predict4/street2.jpg')
img
# Out:
# array([[[ 87,  74, 160],
#         [ 47,  32, 130],
#         [ 26,   7, 134],
#         ...,
#         [ 59,  58,  54],
#         [ 46,  45,  41],
#         [ 20,  19,  15]],
#
#        [[114, 100, 188],
#         [ 55,  41, 142],
#         [ 34,  16, 141],
#         ...,
#         [ 46,  45,  41],
#         [ 44,  43,  39],
#         [ 19,  18,  14]],
#
#        [[120, 108, 198],
#         [ 53,  41, 141],
#         [ 33,  17, 142],
#         ...,
#         [ 33,  34,  30],
#         [ 33,  32,  28],
#         [ 15,  14,  10]],
#
#        ...,
#
#        [[ 41,  41,  41],
#         [ 53,  53,  53],
#         [ 57,  59,  59],
#         ...,
#         [ 34,  46,  46],
#         [ 28,  40,  40],
#         [ 26,  38,  38]],
#
#        [[ 41,  41,  41],
#         [ 51,  51,  51],
#         [ 55,  57,  57],
#         ...,
#         [ 32,  44,  44],
#         [ 25,  37,  37],
#         [ 25,  37,  37]],
#
#        [[ 40,  40,  40],
#         [ 51,  51,  51],
#         [ 54,  56,  56],
# ...

# %%
results =model.predict('/content/street.jpg',save=True, device='cpu')
# Out:
# image 1/1 /content/street.jpg: 448x640 1 tie, 7 persons, 551.8ms
# Speed: 5.2ms preprocess, 551.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4

# %%
img=cv2.imread('/content/runs/detect/predict4/street.jpg')
img
# Out:
# array([[[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [202, 202, 202],
#         [188, 188, 188],
#         [ 56,  56,  56]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [129, 129, 129],
#         [214, 214, 214],
#         [153, 153, 153]],
#
#        [[  5,   5,   5],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [ 92,  92,  92],
#         [218, 218, 218],
#         [147, 147, 147]],
#
#        ...,
#
#        [[ 15,  15,  15],
#         [ 17,  17,  17],
#         [ 14,  14,  14],
#         ...,
#         [ 25,  25,  25],
#         [ 25,  25,  25],
#         [ 37,  37,  37]],
#
#        [[  1,   1,   1],
#         [  5,   5,   5],
#         [  1,   1,   1],
#         ...,
#         [ 34,  34,  34],
#         [ 22,  22,  22],
#         [ 50,  50,  50]],
#
#        [[ 22,  22,  22],
#         [ 24,  24,  24],
#         [  6,   6,   6],
# ...
