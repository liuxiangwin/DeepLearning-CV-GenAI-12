# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load a model
# model = YOLO("yolov8n.pt")  #  ---  detection (n,s,m,l,x)
# model = YOLO("yolov8n-cls.pt")  #  --- classification
# model = YOLO('yolov8n-seg.pt')  #  --- segmentation
# model = YOLO('yolov8n-pose.pt') #  --- Pose / keypoint detection

# %%
#  ---  detection
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
model = YOLO("yolov8n.pt")
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/PEOPLE.mp4', save=True)

# %%
# detection model hardhat vs Safety Vest detection model
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install
import torch
import utils

yolov5path = "/content/drive/MyDrive/CV Course/code files/yolo5_hardhat/runs/train/exp/weights/last.pt"
# !python detect.py --weights "/content/drive/MyDrive/CV Course/code files/yolo5_hardhat/runs/train/exp/weights/last.pt" --conf 0.5 --source '/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/hardhat original.mp4'

# %%
  # ---  clss
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
model=YOLO('yolov8m-cls.pt')
# model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/livingroom.mp4', save=True)
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/PEOPLE.mp4', save=True,conf=0.5)

# %%
  # weather classification
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
model=YOLO('/content/drive/MyDrive/CV Course/code files/ImageClassificationYOLOv8/classify/train/weights/last.pt')
# model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/livingroom.mp4', save=True)
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/cloudy.mp4', save=True,conf=0.5)
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/rainy.mp4', save=True,conf=0.5)
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/snowy.mp4', save=True,conf=0.5)
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/sunny.mp4', save=True,conf=0.5)

# %%
#  ---  segmention
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
model=YOLO('yolov8n-seg.pt')
# model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/livingroom.mp4', save=True)
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/PEOPLE.mp4', save=True, conf=0.5)

# %%
#  ---  segmention pothole
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

model=YOLO('/content/drive/MyDrive/CV Course/code files/ImageSegmentationYOLOv8/segment/train2/weights/last.pt')
# model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/livingroom.mp4', save=True)
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/potholes.mp4', save=True, conf=0.5,)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/309) /content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/potholes.mp4: 640x384 4 potholes, 158.7ms
# video 1/1 (2/309) /content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/potholes.mp4: 640x384 4 potholes, 213.0ms
# video 1/1 (3/309) /content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/potholes.mp4: 640x384 3 potholes, 192.6ms
# ...

# %%
#  ---  keypoint
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
model=YOLO('yolov8n-pose.pt')
# model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/livingroom.mp4', save=True)
model('/content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/footlball playing.mp4', save=True,conf=0.5)
# Out:
# ...
# 100%|██████████| 6.51M/6.51M [00:00<00:00, 212MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/130) /content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/footlball playing.mp4: 384x640 1 person, 247.1ms
# video 1/1 (2/130) /content/drive/MyDrive/CV Course/DATA/YOLO OBJECT TRACKER/footlball playing.mp4: 384x640 1 person, 170.0ms
# ...
