# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.4/715.4 kB 10.7 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

model =YOLO('yolov8n-pose.pt')
# Out:
# ...
# 100%|██████████| 6.51M/6.51M [00:00<00:00, 91.7MB/s]

# %%
# results=model.train(data='config.yaml', epochs=100, imgsz=640)

# !yolo train data=coco128.yaml model=model epochs=100 imgsz=640

# %%
import cv2
from google.colab.patches import cv2_imshow

img_path = '/content/drive/MyDrive/CV Course/DATA/YOLO_POSE_KEYPOINT_DETECTION/street.jpg'
img=cv2.imread(img_path)
# model=YOLO('model_path')

results = model.predict(img_path , save=True, imgsz=320,conf=0.7)
# Out:
# image 1/1 /content/drive/MyDrive/CV Course/DATA/YOLO_POSE_KEYPOINT_DETECTION/street.jpg: 224x320 1 person, 109.9ms
# Speed: 13.2ms preprocess, 109.9ms inference, 1009.4ms postprocess per image at shape (1, 3, 224, 320)
# Results saved to runs/pose/predict

# %%
img = cv2.imread('/content/runs/pose/predict/street.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x512>

# %%
img_path = '/content/drive/MyDrive/CV Course/DATA/YOLO_POSE_KEYPOINT_DETECTION/street2.jpg'
img=cv2.imread(img_path)
# model=YOLO('model_path')

results = model.predict(img_path , save=True, imgsz=320,conf=0.7)
img = cv2.imread('/content/runs/pose/predict/street2.jpg')
cv2_imshow(img)
# Out:
# image 1/1 /content/drive/MyDrive/CV Course/DATA/YOLO_POSE_KEYPOINT_DETECTION/street2.jpg: 192x320 1 person, 97.3ms
# Speed: 1.3ms preprocess, 97.3ms inference, 1.8ms postprocess per image at shape (1, 3, 192, 320)
# Results saved to runs/pose/predict
# <PIL.Image.Image image mode=RGB size=768x431>

# %%
def posedetect(img_file):
  img_path = '/content/drive/MyDrive/CV Course/DATA/YOLO_POSE_KEYPOINT_DETECTION/'+img_file
  img=cv2.imread(img_path)
  # model=YOLO('model_path')

  results = model.predict(img_path ,stream=True, save=True, imgsz=320,conf=0.7)
  img = cv2.imread('/content/runs/pose/predict/'+img_file)
  cv2_imshow(img)

# %%
img_file='Talking.mp4'
posedetect(img_file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-01c0f43bfa60> in <cell line: 2>()
#       1 img_file='Talking.mp4'
# ----> 2 posedetect(img_file)
#
# <ipython-input-1-963319422c8f> in posedetect(img_file)
#       6   results = model.predict(img_path ,stream=True, save=True, imgsz=320,conf=0.7)
#       7   img = cv2.imread('/content/runs/pose/predict/'+img_file)
# ----> 8   cv2_imshow(img)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
